# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold
import xgboost as xgb

def gini(actual, pred, cmpcol = 0, sortcol = 1):
    assert( len(actual) == len(pred) )
    all = np.asarray(np.c_[ actual, pred, np.arange(len(actual)) ], dtype=np.float)
    all = all[ np.lexsort((all[:,2], -1*all[:,1])) ]
    totalLosses = all[:,0].sum()
    giniSum = all[:,0].cumsum().sum() / totalLosses
    
    giniSum -= (len(actual) + 1) / 2.
    return giniSum / len(actual)

def gini_normalized(a, p):
    return gini(a, p) / gini(a, a)

def gini_xgb(preds, dtrain):
    labels = dtrain.get_label()
    gini_score = gini_normalized(labels, preds)
    return [('gini', gini_score)]

train_path = "C:\\Users\\Rui\\source\\Kaggle\\Safe_Driver_Prediction\\train.csv"
test_path = "C:\\Users\\Rui\\source\\Kaggle\\Safe_Driver_Prediction\\test.csv"

df_train = pd.read_csv(train_path, sep = ',')
df_test = pd.read_csv(test_path, sep = ',')

target_train = df_train['target'].values
id_test = df_test['id'].values

train = np.array(df_train.drop(['target','id'], axis = 1))
test = np.array(df_test.drop(['id'], axis = 1))

from imblearn.over_sampling import SMOTE
sme = SMOTE()
train, target_train = sme.fit_sample(train, target_train)


xgb_preds = []

K = 5
kf = KFold(n_splits = K, random_state = 3228, shuffle = True)


for train_index, test_index in kf.split(train):
    train_X, valid_X = train[train_index], train[test_index]
    train_y, valid_y = target_train[train_index], target_train[test_index]

    # params configuration also from the1owl's kernel
    # https://www.kaggle.com/the1owl/forza-baseline
    xgb_params = {'eta': 0.02, 'max_depth': 4, 'subsample': 0.9, 'colsample_bytree': 0.9, 'objective': 'binary:logistic', 'eval_metric': 'auc', 'seed': 99, 'silent': True}

    d_train = xgb.DMatrix(train_X, train_y)
    d_valid = xgb.DMatrix(valid_X, valid_y)
    d_test = xgb.DMatrix(test)
    
    watchlist = [(d_train, 'train'), (d_valid, 'valid')]
    model = xgb.train(xgb_params, d_train, 5000,  watchlist, feval=gini_xgb, maximize=True, verbose_eval=50, early_stopping_rounds=100)
                        
    xgb_pred = model.predict(d_test)
    xgb_preds.append(list(xgb_pred))
    
    
preds=[]
for i in range(len(xgb_preds[0])):
    sum=0
    for j in range(K):
        sum+=xgb_preds[j][i]
    preds.append(sum / K)

output = pd.DataFrame({'id': id_test, 'target': preds})
output.to_csv("{}-foldCV_avg_sub.csv".format(K), index=False)
# Out:
# [0]	train-gini:0.649698	valid-gini:0.64746
# Multiple eval metrics have been passed: 'valid-gini' will be used for early stopping.
#
# Will train until valid-gini hasn't improved in 100 rounds.
# [50]	train-gini:0.960366	valid-gini:0.960736
# [100]	train-gini:0.966308	valid-gini:0.966849
# [150]	train-gini:0.967346	valid-gini:0.968046
# [200]	train-gini:0.967901	valid-gini:0.96854
# [250]	train-gini:0.968163	valid-gini:0.968721
# [300]	train-gini:0.968607	valid-gini:0.969121
# [350]	train-gini:0.96907	valid-gini:0.969507
# [400]	train-gini:0.969605	valid-gini:0.969976
# [450]	train-gini:0.97003	valid-gini:0.970342
# [500]	train-gini:0.970202	valid-gini:0.970503
# [550]	train-gini:0.970366	valid-gini:0.970641
# [600]	train-gini:0.970518	valid-gini:0.970775
# [650]	train-gini:0.970654	valid-gini:0.970889
# [700]	train-gini:0.970769	valid-gini:0.970981
# [750]	train-gini:0.970951	valid-gini:0.971101
# [800]	train-gini:0.971253	valid-gini:0.971306
# [850]	train-gini:0.971611	valid-gini:0.971582
# [900]	train-gini:0.971918	valid-gini:0.97176
# [950]	train-gini:0.972207	valid-gini:0.971927
# [1000]	train-gini:0.972482	valid-gini:0.972087
# [1050]	train-gini:0.972725	valid-gini:0.972212
# [1100]	train-gini:0.972942	valid-gini:0.972317
# [1150]	train-gini:0.97315	valid-gini:0.972435
# [1200]	train-gini:0.973338	valid-gini:0.972512
# [1250]	train-gini:0.973528	valid-gini:0.97258
# [1300]	train-gini:0.973702	valid-gini:0.972637
# [1350]	train-gini:0.973864	valid-gini:0.972692
# [1400]	train-gini:0.974021	valid-gini:0.972732
# [1450]	train-gini:0.974172	valid-gini:0.972778
# [1500]	train-gini:0.974325	valid-gini:0.972805
# [1550]	train-gini:0.974458	valid-gini:0.972839
# [1600]	train-gini:0.974593	valid-gini:0.972864
# [1650]	train-gini:0.974719	valid-gini:0.972887
# [1700]	train-gini:0.974852	valid-gini:0.97291
# [1750]	train-gini:0.974989	valid-gini:0.972924
# [1800]	train-gini:0.97512	valid-gini:0.972941
# [1850]	train-gini:0.975251	valid-gini:0.97295
# [1900]	train-gini:0.975384	valid-gini:0.972954
# [1950]	train-gini:0.975508	valid-gini:0.972966
# [2000]	train-gini:0.975636	valid-gini:0.972983
# [2050]	train-gini:0.975761	valid-gini:0.972985
# [2100]	train-gini:0.975887	valid-gini:0.972994
# [2150]	train-gini:0.97602	valid-gini:0.973003
# [2200]	train-gini:0.976157	valid-gini:0.972999
# [2250]	train-gini:0.976279	valid-gini:0.972991
# Stopping. Best iteration:
# [2162]	train-gini:0.976049	valid-gini:0.973008
#
# [0]	train-gini:0.527655	valid-gini:0.526527
# Multiple eval metrics have been passed: 'valid-gini' will be used for early stopping.
#
# Will train until valid-gini hasn't improved in 100 rounds.
# [50]	train-gini:0.960654	valid-gini:0.960209
# [100]	train-gini:0.966384	valid-gini:0.965948
# [150]	train-gini:0.96774	valid-gini:0.967297
# [200]	train-gini:0.968075	valid-gini:0.967583
# [250]	train-gini:0.968522	valid-gini:0.968022
# [300]	train-gini:0.968898	valid-gini:0.968333
# [350]	train-gini:0.96937	valid-gini:0.968733
# [400]	train-gini:0.969912	valid-gini:0.969167
# [450]	train-gini:0.970165	valid-gini:0.96932
# [500]	train-gini:0.970243	valid-gini:0.969357
# [550]	train-gini:0.970416	valid-gini:0.969485
# [600]	train-gini:0.970627	valid-gini:0.96966
# [650]	train-gini:0.970751	valid-gini:0.969756
# [700]	train-gini:0.970941	valid-gini:0.96989
# [750]	train-gini:0.971079	valid-gini:0.969957
# [800]	train-gini:0.971241	valid-gini:0.970058
# [850]	train-gini:0.971381	valid-gini:0.970139
# [900]	train-gini:0.971492	valid-gini:0.9702
# [950]	train-gini:0.971652	valid-gini:0.970325
# [1000]	train-gini:0.971898	valid-gini:0.970514
# [1050]	train-gini:0.97219	valid-gini:0.970766
# [1100]	train-gini:0.972478	valid-gini:0.971006
# [1150]	train-gini:0.97273	valid-gini:0.971192
# [1200]	train-gini:0.972968	valid-gini:0.971355
# [1250]	train-gini:0.973186	valid-gini:0.971488
# [1300]	train-gini:0.973396	valid-gini:0.971618
# [1350]	train-gini:0.973594	valid-gini:0.971727
# [1400]	train-gini:0.97377	valid-gini:0.971816
# [1450]	train-gini:0.97394	valid-gini:0.97189
# [1500]	train-gini:0.974093	valid-gini:0.971964
# [1550]	train-gini:0.974256	valid-gini:0.972026
# [1600]	train-gini:0.974399	valid-gini:0.97207
# [1650]	train-gini:0.974549	valid-gini:0.972118
# [1700]	train-gini:0.974694	valid-gini:0.972157
# [1750]	train-gini:0.974829	valid-gini:0.972186
# [1800]	train-gini:0.974973	valid-gini:0.972226
# [1850]	train-gini:0.975119	valid-gini:0.972254
# [1900]	train-gini:0.975263	valid-gini:0.972276
# [1950]	train-gini:0.975405	valid-gini:0.972304
# [2000]	train-gini:0.975538	valid-gini:0.972324
# [2050]	train-gini:0.975672	valid-gini:0.972343
# [2100]	train-gini:0.975806	valid-gini:0.972354
# [2150]	train-gini:0.97592	valid-gini:0.972372
# [2200]	train-gini:0.976035	valid-gini:0.972382
# [2250]	train-gini:0.976165	valid-gini:0.972392
# [2300]	train-gini:0.976298	valid-gini:0.972395
# [2350]	train-gini:0.976433	valid-gini:0.972413
# [2400]	train-gini:0.976554	valid-gini:0.972413
# [2450]	train-gini:0.97668	valid-gini:0.972415
# Stopping. Best iteration:
# [2370]	train-gini:0.976488	valid-gini:0.972418
#
# [0]	train-gini:0.538172	valid-gini:0.537592
# Multiple eval metrics have been passed: 'valid-gini' will be used for early stopping.
#
# Will train until valid-gini hasn't improved in 100 rounds.
# [50]	train-gini:0.960563	valid-gini:0.959576
# [100]	train-gini:0.966389	valid-gini:0.965702
# [150]	train-gini:0.967559	valid-gini:0.966995
# [200]	train-gini:0.968047	valid-gini:0.967487
# [250]	train-gini:0.968404	valid-gini:0.967873
# [300]	train-gini:0.968803	valid-gini:0.96824
# [350]	train-gini:0.96929	valid-gini:0.96868
# [400]	train-gini:0.969773	valid-gini:0.969123
# [450]	train-gini:0.970068	valid-gini:0.969402
# [500]	train-gini:0.970165	valid-gini:0.969477
# [550]	train-gini:0.97036	valid-gini:0.969642
# [600]	train-gini:0.970507	valid-gini:0.969758
# [650]	train-gini:0.97066	valid-gini:0.969891
# [700]	train-gini:0.970812	valid-gini:0.97001
# [750]	train-gini:0.97093	valid-gini:0.970101
# [800]	train-gini:0.971109	valid-gini:0.970233
# [850]	train-gini:0.971252	valid-gini:0.970326
# [900]	train-gini:0.971397	valid-gini:0.970417
# [950]	train-gini:0.971519	valid-gini:0.970488
# [1000]	train-gini:0.971699	valid-gini:0.970602
# [1050]	train-gini:0.972012	valid-gini:0.970849
# [1100]	train-gini:0.972296	valid-gini:0.971048
# [1150]	train-gini:0.972576	valid-gini:0.971228
# [1200]	train-gini:0.972839	valid-gini:0.971382
# [1250]	train-gini:0.97308	valid-gini:0.97152
# [1300]	train-gini:0.973288	valid-gini:0.97164
# [1350]	train-gini:0.973494	valid-gini:0.971742
# [1400]	train-gini:0.973695	valid-gini:0.971835
# [1450]	train-gini:0.973871	valid-gini:0.97191
# [1500]	train-gini:0.974038	valid-gini:0.971987
# [1550]	train-gini:0.974207	valid-gini:0.972045
# [1600]	train-gini:0.974371	valid-gini:0.972108
# [1650]	train-gini:0.974521	valid-gini:0.972159
# [1700]	train-gini:0.974661	valid-gini:0.972184
# [1750]	train-gini:0.974806	valid-gini:0.972212
# [1800]	train-gini:0.97494	valid-gini:0.97224
# [1850]	train-gini:0.975093	valid-gini:0.972272
# [1900]	train-gini:0.975239	valid-gini:0.972289
# [1950]	train-gini:0.975385	valid-gini:0.972301
# [2000]	train-gini:0.975524	valid-gini:0.97233
# [2050]	train-gini:0.975656	valid-gini:0.972344
# [2100]	train-gini:0.975796	valid-gini:0.972357
# [2150]	train-gini:0.975929	valid-gini:0.972377
# [2200]	train-gini:0.976072	valid-gini:0.972388
# [2250]	train-gini:0.976207	valid-gini:0.9724
# [2300]	train-gini:0.976337	valid-gini:0.9724
# [2350]	train-gini:0.976459	valid-gini:0.972403
# [2400]	train-gini:0.976575	valid-gini:0.972406
# [2450]	train-gini:0.976685	valid-gini:0.972412
# [2500]	train-gini:0.976803	valid-gini:0.972406
# Stopping. Best iteration:
# [2429]	train-gini:0.976638	valid-gini:0.972413
#
# [0]	train-gini:0.526288	valid-gini:0.526405
# Multiple eval metrics have been passed: 'valid-gini' will be used for early stopping.
#
# Will train until valid-gini hasn't improved in 100 rounds.
# [50]	train-gini:0.961089	valid-gini:0.961807
# [100]	train-gini:0.966496	valid-gini:0.966715
# [150]	train-gini:0.967534	valid-gini:0.967724
# [200]	train-gini:0.968001	valid-gini:0.968127
# [250]	train-gini:0.968365	valid-gini:0.96848
# [300]	train-gini:0.968797	valid-gini:0.968831
# [350]	train-gini:0.969219	valid-gini:0.969219
# [400]	train-gini:0.969758	valid-gini:0.969655
# [450]	train-gini:0.970235	valid-gini:0.970042
# [500]	train-gini:0.970414	valid-gini:0.970169
# [550]	train-gini:0.970617	valid-gini:0.970324
# [600]	train-gini:0.970745	valid-gini:0.970414
# [650]	train-gini:0.970897	valid-gini:0.970536
# [700]	train-gini:0.971012	valid-gini:0.970614
# [750]	train-gini:0.971159	valid-gini:0.970701
# [800]	train-gini:0.971356	valid-gini:0.970823
# [850]	train-gini:0.971666	valid-gini:0.971064
# [900]	train-gini:0.971974	valid-gini:0.971277
# [950]	train-gini:0.972254	valid-gini:0.971463
# [1000]	train-gini:0.972513	valid-gini:0.971617
# [1050]	train-gini:0.972747	valid-gini:0.971762
# [1100]	train-gini:0.972973	valid-gini:0.971893
# [1150]	train-gini:0.973174	valid-gini:0.971985
# [1200]	train-gini:0.973366	valid-gini:0.972084
# [1250]	train-gini:0.97354	valid-gini:0.972156
# [1300]	train-gini:0.973713	valid-gini:0.97223
# [1350]	train-gini:0.973868	valid-gini:0.972281
# [1400]	train-gini:0.974019	valid-gini:0.972337
# [1450]	train-gini:0.97417	valid-gini:0.972375
# [1500]	train-gini:0.974309	valid-gini:0.972409
# [1550]	train-gini:0.974449	valid-gini:0.972443
# [1600]	train-gini:0.974595	valid-gini:0.972465
# [1650]	train-gini:0.974745	valid-gini:0.972491
# [1700]	train-gini:0.97489	valid-gini:0.972517
# [1750]	train-gini:0.975038	valid-gini:0.972536
# [1800]	train-gini:0.975166	valid-gini:0.972552
# [1850]	train-gini:0.9753	valid-gini:0.972563
# [1900]	train-gini:0.975438	valid-gini:0.972577
# [1950]	train-gini:0.975575	valid-gini:0.972585
# [2000]	train-gini:0.975707	valid-gini:0.972599
# [2050]	train-gini:0.975838	valid-gini:0.972611
# [2100]	train-gini:0.975962	valid-gini:0.972619
# [2150]	train-gini:0.976099	valid-gini:0.972643
# [2200]	train-gini:0.976239	valid-gini:0.972674
# [2250]	train-gini:0.976362	valid-gini:0.972691
# [2300]	train-gini:0.976482	valid-gini:0.972695
# [2350]	train-gini:0.976595	valid-gini:0.972693
# [2400]	train-gini:0.976717	valid-gini:0.972694
# Stopping. Best iteration:
# [2306]	train-gini:0.976495	valid-gini:0.972702
#
# [0]	train-gini:0.527412	valid-gini:0.527514
# Multiple eval metrics have been passed: 'valid-gini' will be used for early stopping.
#
# Will train until valid-gini hasn't improved in 100 rounds.
# [50]	train-gini:0.960722	valid-gini:0.960586
# [100]	train-gini:0.966693	valid-gini:0.966438
# [150]	train-gini:0.967722	valid-gini:0.967206
# [200]	train-gini:0.968121	valid-gini:0.967542
# [250]	train-gini:0.96853	valid-gini:0.96793
# [300]	train-gini:0.968971	valid-gini:0.968351
# [350]	train-gini:0.969376	valid-gini:0.968772
# [400]	train-gini:0.9699	valid-gini:0.969255
# [450]	train-gini:0.970386	valid-gini:0.96972
# [500]	train-gini:0.9708	valid-gini:0.970104
# [550]	train-gini:0.971194	valid-gini:0.970444
# [600]	train-gini:0.971536	valid-gini:0.970742
# [650]	train-gini:0.971826	valid-gini:0.970975
# [700]	train-gini:0.972107	valid-gini:0.971196
# [750]	train-gini:0.972372	valid-gini:0.971404
# [800]	train-gini:0.972624	valid-gini:0.971595
# [850]	train-gini:0.972857	valid-gini:0.971749
# [900]	train-gini:0.973066	valid-gini:0.971873
# [950]	train-gini:0.973268	valid-gini:0.971967
# [1000]	train-gini:0.973471	valid-gini:0.972071
# [1050]	train-gini:0.97365	valid-gini:0.972136
# [1100]	train-gini:0.973829	valid-gini:0.972199
# [1150]	train-gini:0.973994	valid-gini:0.972266
# [1200]	train-gini:0.974148	valid-gini:0.972321
# [1250]	train-gini:0.97429	valid-gini:0.972358
# [1300]	train-gini:0.974426	valid-gini:0.9724
# [1350]	train-gini:0.974571	valid-gini:0.972428
# [1400]	train-gini:0.974715	valid-gini:0.972466
# [1450]	train-gini:0.97487	valid-gini:0.97249
# [1500]	train-gini:0.975016	valid-gini:0.972517
# [1550]	train-gini:0.975157	valid-gini:0.97254
# [1600]	train-gini:0.975304	valid-gini:0.972561
# [1650]	train-gini:0.975446	valid-gini:0.972584
# [1700]	train-gini:0.975574	valid-gini:0.972587
# [1750]	train-gini:0.975705	valid-gini:0.972593
# [1800]	train-gini:0.975829	valid-gini:0.972603
# [1850]	train-gini:0.975967	valid-gini:0.972607
# [1900]	train-gini:0.976095	valid-gini:0.972593
# Stopping. Best iteration:
# [1825]	train-gini:0.975898	valid-gini:0.972608
