# %%
import os
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold
import xgboost as xgb

cwd=os.getcwd()+'/'

def gini(actual, pred, cmpcol = 0, sortcol = 1):
    assert( len(actual) == len(pred) )
    all = np.asarray(np.c_[ actual, pred, np.arange(len(actual)) ], dtype=np.float)
    all = all[ np.lexsort((all[:,2], -1*all[:,1])) ]
    totalLosses = all[:,0].sum()
    giniSum = all[:,0].cumsum().sum() / totalLosses
    
    giniSum -= (len(actual) + 1) / 2.
    return giniSum / len(actual)

def gini_normalized(a, p):
    return gini(a, p) / gini(a, a)

def gini_xgb(preds, dtrain):
    labels = dtrain.get_label()
    gini_score = gini_normalized(labels, preds)
    return [('gini', gini_score)]

# %%
df_train = pd.read_csv('./training.csv')
df_test = pd.read_csv('./test.csv')

target_train = df_train['IsBadBuy'].values
id_test = df_test['RefId'].values

df_train = df_train.drop(['IsBadBuy','RefId'],axis=1)
df_test= df_test.drop(['RefId'], axis = 1)
combine= pd.concat([df_train, df_test],axis=0)

# %%
drop_list = ['PRIMEUNIT', 'AUCGUART', 'Model', 'Trim', 
             'SubModel', 'WheelType', 'BYRNO', 'VNZIP1']

combine.PurchDate = pd.to_datetime(combine.PurchDate, format=r'%m/%d/%Y').astype(np.int64)//10**15
    
# add engine feature
combine['Engine'] = combine.SubModel.str.extract('\s+(\d+.\d+)L', expand = True).astype('float64')

# now we can start the drop list
combine = combine.drop(drop_list, axis=1)

num_features = combine.select_dtypes(include = ['float64', 'int64', 'bool']).columns.values
cat_features = combine.select_dtypes(include = ['object']).columns.values

# %%
cat_features
# Out:
# array(['Auction', 'Make', 'Color', 'Transmission', 'Nationality', 'Size',
#        'TopThreeAmericanName', 'VNST'], dtype=object)

# %%
cat_na_features = []
for column in cat_features:
    if combine[column].isnull().sum()>0:
        cat_na_features.append(column)
cat_na_features
# Out:
# ['Color', 'Transmission', 'Nationality', 'Size', 'TopThreeAmericanName']

# %%
for column in cat_features:
    temp = pd.get_dummies(pd.Series(combine[column]))
    combine = pd.concat([combine,temp],axis=1)
    combine = combine.drop([column],axis=1)

# %%
df_train=combine[:df_train.shape[0]]
df_test=combine[df_train.shape[0]:]

train = np.array(df_train)
test = np.array(df_test)

print ("The train shape is:",train.shape)
print ('The test shape is:',test.shape)
# Out:
# The train shape is: (72983, 131)
# The test shape is: (48707, 131)

# %%
xgb_preds = []


K = 5
kf = KFold(n_splits = K, random_state = 3228,shuffle=True)


for train_index, test_index in kf.split(train):
    train_X, valid_X = train[train_index], train[test_index]
    train_y, valid_y = target_train[train_index], target_train[test_index]

    # params configuration also from the1owl's kernel
    # https://www.kaggle.com/the1owl/forza-baseline
    xgb_params = {'eta': 0.02, 'max_depth': 5, 'subsample': 0.9, 'colsample_bytree': 0.9, 
                  'objective': 'binary:logistic', 'eval_metric': 'auc', 'seed': 99, 'silent': True}

    d_train = xgb.DMatrix(train_X, train_y)
    d_valid = xgb.DMatrix(valid_X, valid_y)
    d_test = xgb.DMatrix(test)
    
    watchlist = [(d_train, 'train'), (d_valid, 'valid')]
    model = xgb.train(xgb_params, d_train, 5000,  watchlist, feval=gini_xgb, maximize=True, verbose_eval=50, early_stopping_rounds=100)
                        
    xgb_pred = model.predict(d_test)
    xgb_preds.append(list(xgb_pred))
    
    
    
preds=[]
for i in range(len(xgb_preds[0])):
    sum=0
    for j in range(K):
        sum+=xgb_preds[j][i]
    preds.append(sum / K)

output = pd.DataFrame({'RefId': id_test, 'IsBadBuy': preds})
output.to_csv("{}-foldCV_avg_sub.csv".format(K), index=False)
# Out:
# [0]	train-gini:0.318951	valid-gini:0.311681
# Multiple eval metrics have been passed: 'valid-gini' will be used for early stopping.
#
# Will train until valid-gini hasn't improved in 100 rounds.
# [50]	train-gini:0.517047	valid-gini:0.514266
# [100]	train-gini:0.527737	valid-gini:0.519109
# [150]	train-gini:0.541602	valid-gini:0.525435
# [200]	train-gini:0.563605	valid-gini:0.532111
# [250]	train-gini:0.581184	valid-gini:0.537899
# [300]	train-gini:0.595471	valid-gini:0.541909
# [350]	train-gini:0.609043	valid-gini:0.545437
# [400]	train-gini:0.620636	valid-gini:0.548431
# [450]	train-gini:0.631493	valid-gini:0.550676
# [500]	train-gini:0.642446	valid-gini:0.552954
# [550]	train-gini:0.65254	valid-gini:0.553848
# [600]	train-gini:0.662797	valid-gini:0.555657
# [650]	train-gini:0.671854	valid-gini:0.556737
# [700]	train-gini:0.68127	valid-gini:0.558364
# [750]	train-gini:0.688926	valid-gini:0.559751
# [800]	train-gini:0.696721	valid-gini:0.560519
# [850]	train-gini:0.70452	valid-gini:0.561637
# [900]	train-gini:0.713031	valid-gini:0.562425
# [950]	train-gini:0.721321	valid-gini:0.56327
# [1000]	train-gini:0.728609	valid-gini:0.563741
# [1050]	train-gini:0.734881	valid-gini:0.563578
# [1100]	train-gini:0.741585	valid-gini:0.564088
# [1150]	train-gini:0.748169	valid-gini:0.564633
# [1200]	train-gini:0.754163	valid-gini:0.565863
# [1250]	train-gini:0.760857	valid-gini:0.565697
# [1300]	train-gini:0.766283	valid-gini:0.565706
# Stopping. Best iteration:
# [1224]	train-gini:0.756895	valid-gini:0.565888
#
# [0]	train-gini:0.312802	valid-gini:0.254274
# Multiple eval metrics have been passed: 'valid-gini' will be used for early stopping.
#
# Will train until valid-gini hasn't improved in 100 rounds.
# [50]	train-gini:0.522042	valid-gini:0.467675
# [100]	train-gini:0.533685	valid-gini:0.476734
# [150]	train-gini:0.546097	valid-gini:0.483285
# [200]	train-gini:0.567765	valid-gini:0.494839
# [250]	train-gini:0.587835	valid-gini:0.502668
# [300]	train-gini:0.603735	valid-gini:0.507518
# [350]	train-gini:0.615849	valid-gini:0.510969
# [400]	train-gini:0.627714	valid-gini:0.513976
# [450]	train-gini:0.637198	valid-gini:0.516082
# [500]	train-gini:0.647731	valid-gini:0.517843
# [550]	train-gini:0.657026	valid-gini:0.519442
# [600]	train-gini:0.666727	valid-gini:0.521657
# [650]	train-gini:0.674624	valid-gini:0.523082
# [700]	train-gini:0.683635	valid-gini:0.523997
# [750]	train-gini:0.691699	valid-gini:0.525362
# [800]	train-gini:0.699981	valid-gini:0.527095
# [850]	train-gini:0.707123	valid-gini:0.527871
# [900]	train-gini:0.713844	valid-gini:0.528129
# [950]	train-gini:0.722664	valid-gini:0.530146
# [1000]	train-gini:0.729274	valid-gini:0.530723
# [1050]	train-gini:0.737009	valid-gini:0.53186
# [1100]	train-gini:0.743313	valid-gini:0.531972
# [1150]	train-gini:0.749473	valid-gini:0.532082
# [1200]	train-gini:0.755929	valid-gini:0.532357
# [1250]	train-gini:0.762168	valid-gini:0.532763
# [1300]	train-gini:0.76866	valid-gini:0.533102
# [1350]	train-gini:0.774905	valid-gini:0.533222
# [1400]	train-gini:0.780242	valid-gini:0.533617
# [1450]	train-gini:0.7849	valid-gini:0.534073
# [1500]	train-gini:0.789195	valid-gini:0.534408
# [1550]	train-gini:0.795023	valid-gini:0.534177
# [1600]	train-gini:0.800655	valid-gini:0.534147
# Stopping. Best iteration:
# [1508]	train-gini:0.790025	valid-gini:0.53452
#
# [0]	train-gini:0.30798	valid-gini:0.276968
# Multiple eval metrics have been passed: 'valid-gini' will be used for early stopping.
#
# Will train until valid-gini hasn't improved in 100 rounds.
# [50]	train-gini:0.519024	valid-gini:0.497522
# [100]	train-gini:0.530723	valid-gini:0.502829
# [150]	train-gini:0.543457	valid-gini:0.509841
# [200]	train-gini:0.564163	valid-gini:0.517136
# [250]	train-gini:0.583743	valid-gini:0.522981
# [300]	train-gini:0.598415	valid-gini:0.526141
# [350]	train-gini:0.612262	valid-gini:0.528029
# [400]	train-gini:0.624616	valid-gini:0.529991
# [450]	train-gini:0.635703	valid-gini:0.531659
# [500]	train-gini:0.646029	valid-gini:0.53303
# [550]	train-gini:0.656078	valid-gini:0.534408
# [600]	train-gini:0.666264	valid-gini:0.535978
# [650]	train-gini:0.675134	valid-gini:0.536715
# [700]	train-gini:0.683343	valid-gini:0.53694
# [750]	train-gini:0.690872	valid-gini:0.537377
# [800]	train-gini:0.698963	valid-gini:0.538033
# [850]	train-gini:0.705816	valid-gini:0.538291
# [900]	train-gini:0.713883	valid-gini:0.538851
# [950]	train-gini:0.721343	valid-gini:0.538908
# [1000]	train-gini:0.72856	valid-gini:0.539631
# [1050]	train-gini:0.73616	valid-gini:0.539864
# [1100]	train-gini:0.743619	valid-gini:0.540224
# [1150]	train-gini:0.749055	valid-gini:0.540007
# [1200]	train-gini:0.754456	valid-gini:0.540289
# Stopping. Best iteration:
# [1122]	train-gini:0.746012	valid-gini:0.540435
#
# [0]	train-gini:0.48053	valid-gini:0.494431
# Multiple eval metrics have been passed: 'valid-gini' will be used for early stopping.
#
# Will train until valid-gini hasn't improved in 100 rounds.
# [50]	train-gini:0.509649	valid-gini:0.520139
# [100]	train-gini:0.524394	valid-gini:0.52655
# [150]	train-gini:0.541745	valid-gini:0.53351
# [200]	train-gini:0.562739	valid-gini:0.541929
# [250]	train-gini:0.580975	valid-gini:0.548354
# [300]	train-gini:0.595167	valid-gini:0.551512
# [350]	train-gini:0.609625	valid-gini:0.55523
# [400]	train-gini:0.622236	valid-gini:0.557426
# [450]	train-gini:0.634199	valid-gini:0.56059
# [500]	train-gini:0.645125	valid-gini:0.562285
# [550]	train-gini:0.655816	valid-gini:0.563382
# [600]	train-gini:0.664785	valid-gini:0.564535
# [650]	train-gini:0.67407	valid-gini:0.565543
# [700]	train-gini:0.682953	valid-gini:0.56623
# [750]	train-gini:0.690697	valid-gini:0.56675
# [800]	train-gini:0.699258	valid-gini:0.567825
# [850]	train-gini:0.706945	valid-gini:0.568406
# [900]	train-gini:0.714674	valid-gini:0.568698
# [950]	train-gini:0.721146	valid-gini:0.56891
# [1000]	train-gini:0.727762	valid-gini:0.569231
# [1050]	train-gini:0.73539	valid-gini:0.569524
# [1100]	train-gini:0.741952	valid-gini:0.569801
# [1150]	train-gini:0.748742	valid-gini:0.569899
# [1200]	train-gini:0.754974	valid-gini:0.569874
# Stopping. Best iteration:
# [1127]	train-gini:0.74546	valid-gini:0.570294
#
# [0]	train-gini:0.477562	valid-gini:0.466229
# Multiple eval metrics have been passed: 'valid-gini' will be used for early stopping.
#
# Will train until valid-gini hasn't improved in 100 rounds.
# [50]	train-gini:0.512878	valid-gini:0.491892
# [100]	train-gini:0.526804	valid-gini:0.50042
# [150]	train-gini:0.543414	valid-gini:0.510104
# [200]	train-gini:0.563228	valid-gini:0.519909
# [250]	train-gini:0.583592	valid-gini:0.525977
# [300]	train-gini:0.598319	valid-gini:0.529704
# [350]	train-gini:0.611064	valid-gini:0.532064
# [400]	train-gini:0.622417	valid-gini:0.533568
# [450]	train-gini:0.633405	valid-gini:0.535037
# [500]	train-gini:0.645231	valid-gini:0.536708
# [550]	train-gini:0.654561	valid-gini:0.537426
# [600]	train-gini:0.663673	valid-gini:0.538343
# [650]	train-gini:0.673181	valid-gini:0.538709
# [700]	train-gini:0.682993	valid-gini:0.540048
# [750]	train-gini:0.691164	valid-gini:0.540637
# [800]	train-gini:0.699651	valid-gini:0.540691
# [850]	train-gini:0.707702	valid-gini:0.541533
# [900]	train-gini:0.715343	valid-gini:0.542274
# [950]	train-gini:0.722501	valid-gini:0.54228
# [1000]	train-gini:0.730035	valid-gini:0.542911
# [1050]	train-gini:0.736983	valid-gini:0.543613
# [1100]	train-gini:0.744666	valid-gini:0.543714
# [1150]	train-gini:0.751514	valid-gini:0.543895
# [1200]	train-gini:0.756892	valid-gini:0.544318
# [1250]	train-gini:0.763458	valid-gini:0.544619
# [1300]	train-gini:0.769914	valid-gini:0.544805
# [1350]	train-gini:0.775974	valid-gini:0.544684
# [1400]	train-gini:0.780983	valid-gini:0.545328
# [1450]	train-gini:0.786196	valid-gini:0.545244
# [1500]	train-gini:0.79144	valid-gini:0.545139
# Stopping. Best iteration:
# [1408]	train-gini:0.781744	valid-gini:0.54545
